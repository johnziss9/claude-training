# %%
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in ./venv/lib/python3.13/site-packages (0.111.0)
# Requirement already satisfied: python-dotenv in ./venv/lib/python3.13/site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./venv/lib/python3.13/site-packages (from anthropic) (4.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./venv/lib/python3.13/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in ./venv/lib/python3.13/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in ./venv/lib/python3.13/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./venv/lib/python3.13/site-packages (from anthropic) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./venv/lib/python3.13/site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in ./venv/lib/python3.13/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in ./venv/lib/python3.13/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in ./venv/lib/python3.13/site-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: certifi in ./venv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in ./venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
# Make a list of initial messages
messages = []

# Use a 'white True' loop to run the chatbot forever
while True:
    # Get user input
    user_input = input("> ")
    print(">", user_input)

    # Add the user input to the list of messages
    add_user_message(messages, user_input)

    # Call Claude with that chat function
    answer = chat(messages)

    # Add generated text to the list of messages
    add_user_message(messages, answer)

    # Print the generated text
    print("---")
    print(answer)
    print("---")
# Out:
# > what's c#
# # C# (C-Sharp)
#
# ## What is it?
# C# is a **modern, object-oriented programming language** developed by **Microsoft** as part of the **.NET platform**. It was created by **Anders Hejlsberg** and released in **2000**.
#
# ---
#
# ## Key Features
# - **Object-Oriented** – Uses classes, objects, inheritance, etc.
# - **Strongly Typed** – Variables must have defined types
# - **Cross-Platform** – Runs on Windows, Mac, Linux (via .NET Core)
# - **Garbage Collection** – Automatic memory management
# - **Type-Safe** – Reduces errors at compile time
#
# ---
#
# ## Common Uses
# | Area | Example |
# |------|---------|
# | 🎮 Game Development | Unity games |
# | 🌐 Web Development | ASP.NET websites/APIs |
# | 🖥️ Desktop Apps | Windows applications |
# | 📱 Mobile Apps | Xamarin / MAUI |
# | ☁️ Cloud Services | Azure applications |
#
# ---
#
# ## Simple Example
# ```csharp
# using System;
#
# class Hello {
#     static void Main() {
#         Console.WriteLine("Hello, World!");
#     }
# }
# ```
#
# ---
#
# ## C# vs Other Languages
# - Similar to **Java** in syntax
# - More modern features than **C++**
# - Mainly used in the **Microsoft ecosystem**
#
# ---
#
# Would you like to learn more about any specific aspect of C#?
# > best use of it
# # C# (C-Sharp)
#
# ## What is C#?
# C# is a **modern, object-oriented programming language** developed by **Microsoft** in 2000. It runs on the **.NET platform** and is designed to be:
# - Simple
# - Powerful
# - Type-safe
# - Object-oriented
#
# ---
#
# ## Best Uses of C#
#
# ### 1. 🎮 Game Development
# - Most popular use with **Unity game engine**
# - Powers thousands of games (mobile, PC, console)
#
# ### 2. 🖥️ Desktop Applications
# - Windows apps using **WPF** or **WinForms**
# - Cross-platform apps with **MAUI**
#
# ### 3. 🌐 Web Development
# - Backend APIs with **ASP.NET Core**
# - Fast and scalable web applications
#
# ### 4. 📱 Mobile Apps
# - Cross-platform mobile with **.NET MAUI**
# - iOS and Android from one codebase
#
# ### 5. ☁️ Cloud & Enterprise
# - **Azure** cloud services
# - Large-scale business applications
#
# ---
#
# ## Quick Example
# ```csharp
# // Hello World in C#
# using System;
#
# class Program {
#     static void Main() {
#         Console.WriteLine("Hello, World!");
#     }
# }
# ```
#
# ---
#
# ## Why Learn C#?
# | Feature | Benefit |
# |---------|---------|
# | Strong typing | Fewer bugs |
# | Great tooling | Visual Studio support |
# | High demand | Good job market |
# | Versatile | Many use cases |
#
# **Bottom line:** C# is best for **game dev, Windows apps, and enterprise web backends.**
# > tell me about a similar language
# # C# (C-Sharp)
#
# ## What is C#?
# C# is a **modern, object-oriented programming language** developed by **Microsoft** in 2000. It runs on the **.NET platform** and is strongly typed, compiled, and versatile.
#
# ---
#
# ## Best Uses of C#
#
# | Use Case | Details |
# |----------|---------|
# | **Game Development** | Primary language for **Unity** game engine |
# | **Windows Apps** | Desktop applications with WPF/WinForms |
# | **Web Development** | Backend APIs with **ASP.NET Core** |
# | **Enterprise Software** | Large scale business applications |
# | **Mobile Apps** | Cross-platform with **Xamarin/.NET MAUI** |
# | **Cloud Apps** | Works great with **Microsoft Azure** |
#
# ---
#
# ## Similar Language - Java ☕
#
# C# and Java are **extremely similar** because:
# - Both are **object-oriented**
# - Both use **garbage collection**
# - Both have **similar syntax**
# - Both are **strongly typed**
#
# ### Quick Comparison
# ```
# C#           vs      Java
# ---------------------------------
# .NET runtime         JVM runtime
# Microsoft            Oracle
# Unity games          Android apps
# ASP.NET web          Spring web
# C# LINQ              Java Streams
# ```
#
# ### Key Differences
# - C# has **more modern features** (LINQ, async/await came first)
# - Java runs on **more platforms** historically
# - C# is **better for Windows/games**
# - Java is **bigger in enterprise/Android**
#
# ---
#
# **Bottom line:** C# is powerful, well-supported, and great if you're in the Microsoft/Unity ecosystem 🎯
# >
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 23
#      19         )
#      20         return message.content[0].text
#      21
#      22     # Add generated text to the list of messages
# ---> 23     generated_text = chat(messages)
#      24
#      25     # Print the generated text
#      26     print(generated_text)
#
# Cell In[3], line 15, in chat(messages)
#      14     def chat(messages):
# ---> 15         message = client.messages.create(
#      16             model=model,
#      17             max_tokens=1000,
#      18             messages=messages,
#
# File ~/Projects/Claude/venv/lib/python3.13/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File ~/Projects/Claude/venv/lib/python3.13/site-packages/anthropic/resources/messages/messages.py:1018, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#    1011 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#    1012     warnings.warn(
#    1013         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1014         UserWarning,
#    1015         stacklevel=3,
#    1016     )
# -> 1018 return self._post(
#    1019     "/v1/messages",
#    1020     body=maybe_transform(
#    1021         {
#    1022             "max_tokens": max_tokens,
#    1023             "messages": messages,
#    1024             "model": model,
#    1025             "cache_control": cache_control,
#    1026             "container": container,
#    1027             "inference_geo": inference_geo,
#    1028             "metadata": metadata,
#    1029             "output_config": output_config,
#    1030             "service_tier": service_tier,
#    1031             "stop_sequences": stop_sequences,
#    1032             "stream": stream,
#    1033             "system": system,
#    1034             "temperature": temperature,
#    1035             "thinking": thinking,
#    1036             "tool_choice": tool_choice,
#    1037             "tools": tools,
#    1038             "top_k": top_k,
#    1039             "top_p": top_p,
#    1040         },
#    1041         message_create_params.MessageCreateParamsStreaming
#    1042         if stream
#    1043         else message_create_params.MessageCreateParamsNonStreaming,
#    1044     ),
#    1045     options=make_request_options(
#    1046         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1047     ),
#    1048     cast_to=Message,
#    1049     stream=stream or False,
#    1050     stream_cls=Stream[RawMessageStreamEvent],
#    1051 )
#
# File ~/Projects/Claude/venv/lib/python3.13/site-packages/anthropic/_base_client.py:1536, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1527     warnings.warn(
#    1528         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1529         "Please pass raw bytes via the `content` parameter instead.",
#    1530         DeprecationWarning,
#    1531         stacklevel=2,
#    1532     )
#    1533 opts = FinalRequestOptions.construct(
#    1534     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1535 )
# -> 1536 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Projects/Claude/venv/lib/python3.13/site-packages/anthropic/_base_client.py:1137, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1135 try:
#    1136     if chain is None:
# -> 1137         response, prepared = self._attempt_request(
#    1138             model_copy(input_options), stream=stream, retries_taken=retries_taken
#    1139         )
#    1140         if response.is_success:
#    1141             return self._process_response(
#    1142                 cast_to=cast_to,
#    1143                 options=prepared,
#    (...)   1147                 retries_taken=retries_taken,
#    1148             )
#
# File ~/Projects/Claude/venv/lib/python3.13/site-packages/anthropic/_base_client.py:1295, in SyncAPIClient._attempt_request(self, options, stream, retries_taken)
#    1292 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#    1294 try:
# -> 1295     response = self._client.send(
#    1296         request,
#    1297         stream=stream or self._should_stream_response_body(request=request),
#    1298         **kwargs,
#    1299     )
#    1300 except httpx.TimeoutException as err:
#    1301     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/Projects/Claude/venv/lib/python3.13/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Projects/Claude/venv/lib/python3.13/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Projects/Claude/venv/lib/python3.13/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Projects/Claude/venv/lib/python3.13/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Projects/Claude/venv/lib/python3.13/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/Projects/Claude/venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Projects/Claude/venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Projects/Claude/venv/lib/python3.13/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Projects/Claude/venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Projects/Claude/venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Projects/Claude/venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Projects/Claude/venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Projects/Claude/venv/lib/python3.13/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.5/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1285, in SSLSocket.recv(self, buflen, flags)
#    1281     if flags != 0:
#    1282         raise ValueError(
#    1283             "non-zero flags not allowed in calls to recv() on %s" %
#    1284             self.__class__)
# -> 1285     return self.read(buflen)
#    1286 else:
#    1287     return super().recv(buflen, flags)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.5/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1140, in SSLSocket.read(self, len, buffer)
#    1138         return self._sslobj.read(len, buffer)
#    1139     else:
# -> 1140         return self._sslobj.read(len)
#    1141 except SSLError as x:
#    1142     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
